# %%
#Задание 1


class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next
        
def reverse_linked_list(head, tail=None):
    while head is not None:
        head.next, tail, head = tail, head, head.next
    return tail
    

h, a, b, c, d = Node(1), Node(2), Node(3), Node("Внезапно"), Node(5)

h.next = a
a.next = b
b.next = c
c.next = d

print_linked_list(h)
h = reverse_linked_list(h)
print("---")
print_linked_list(h)
# Out:
# [Node with value 1]
# [Node with value 2]
# [Node with value 3]
# [Node with value Внезапно]
# [Node with value 5]
# ---
# [Node with value 5]
# [Node with value Внезапно]
# [Node with value 3]
# [Node with value 2]
# [Node with value 1]

# %%
#Задание 2

class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next
        

h, a, b, c, d, e = Node(5), Node(1), Node(3), Node(2), Node(4), Node(6)

h.next = a
a.next = b
b.next = c
c.next = d
d.next = e

print_linked_list(h)
print('------')

def sort_linked_list(head):
    end = None
    while end != head:
        p = head
        while p.next != end:
            q = p.next
            if p.value > q.value:
                p.value, q.value = q.value, p.value
            p = p.next
        end = p

sort_linked_list(h)
print_linked_list(h)
# Out:
# [Node with value 5]
# [Node with value 1]
# [Node with value 3]
# [Node with value 2]
# [Node with value 4]
# [Node with value 6]
# ------
# [Node with value 1]
# [Node with value 2]
# [Node with value 3]
# [Node with value 4]
# [Node with value 5]
# [Node with value 6]

# %%
#Задание 3.1
import pandas as pd
df = pd.read_csv("C:\\Users\\delux\\Desktop\\data\\tips.csv")
le_masque = df["sex"] == "Male"
le_masque &= df["day"] == "Fri"
le_masque &= df["smoker"] == "Yes"
le_masque &= df["time"] == "Lunch"
print(f'Cреднее значение счета: {df[le_masque]["total_bill"].mean()}')
# Out:
# Cреднее значение счета: 11.386666666666668

# %%
#Задание 3.2

import pandas as pd
df = pd.read_csv("C:\\Users\\delux\\Desktop\\data\\\iris.csv")
le_masque_1 = df["Name"] == "Iris-setosa"
le_masque_2 = df["Name"] == "Iris-versicolor"
le_masque_3 = df["Name"] == "Iris-virginica"
print('Числовые значение по классу Iris-setosa варьируются от минимального значения:\n\n', df[le_masque_1].min(), 
      '\n\nдо максимального:\n\n', df[le_masque_1].max(), '\n-----------------------\n')
print('Числовые значение по классу Iris-versicolor варьируются от минимального значения:\n\n', df[le_masque_2].min(), 
      '\n\nдо максимального:\n\n', df[le_masque_2].max(), '\n-----------------------\n')
print('Числовые значение по классу Iris-virginica варьируются от минимального значения:\n\n', df[le_masque_3].min(), 
      '\n\nдо максимального:\n\n', df[le_masque_3].max())
# Out:
# Числовые значение по классу Iris-setosa варьируются от минимального значения:
#
#  SepalLength            4.3
# SepalWidth             2.3
# PetalLength            1.0
# PetalWidth             0.1
# Name           Iris-setosa
# dtype: object
#
# до максимального:
#
#  SepalLength            5.8
# SepalWidth             4.4
# PetalLength            1.9
# PetalWidth             0.6
# Name           Iris-setosa
# dtype: object
# -----------------------
#
# Числовые значение по классу Iris-versicolor варьируются от минимального значения:
#
#  SepalLength                4.9
# SepalWidth                 2.0
# PetalLength                3.0
# PetalWidth                 1.0
# Name           Iris-versicolor
# dtype: object
#
# до максимального:
#
#  SepalLength                7.0
# SepalWidth                 3.4
# PetalLength                5.1
# PetalWidth                 1.8
# Name           Iris-versicolor
# dtype: object
# -----------------------
#
# Числовые значение по классу Iris-virginica варьируются от минимального значения:
#
#  SepalLength               4.9
# SepalWidth                2.2
# PetalLength               4.5
# PetalWidth                1.4
# Name           Iris-virginica
# dtype: object
#
# до максимального:
#
#  SepalLength               7.9
# SepalWidth                3.8
# PetalLength               6.9
# PetalWidth                2.5
# Name           Iris-virginica
# dtype: object

# %%
#Задание 3.3

import pandas as pd
df = pd.DataFrame({
     'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
     'population': [17.04, 143.5, 9.5, 45.5],
     'square': [2724902, 17125191, 207600, 603628]
 })
df['density'] = df.population/df.square
df.rename(columns={'country': 'страна', 'square': 'площадь'}, inplace=True)
df
# Out:
#        страна  population   площадь   density
# 0  Kazakhstan       17.04   2724902  0.000006
# 1      Russia      143.50  17125191  0.000008
# 2     Belarus        9.50    207600  0.000046
# 3     Ukraine       45.50    603628  0.000075
